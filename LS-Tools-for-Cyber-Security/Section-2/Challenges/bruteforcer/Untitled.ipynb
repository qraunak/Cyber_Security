# %%
import subprocess

# Path to the bruteforcer program and the wordlist file
bruteforcer_path = '.\bruteforcer'
wordlist_path = 'wordlist.txt'

# def run_bruteforce():
# Read the wordlist file and extract passwords
with open(wordlist_path, 'r') as file:
    passwords = [line.strip() for line in file]

for password in passwords:
    # Execute the bruteforcer program with the current password as input
    process = subprocess.Popen([bruteforcer_path], stdin=subprocess.PIPE, stdout=subprocess.PIPE, text=True)
    output, _ = process.communicate(input=password)
#     print('\r',password, end='')
#     # Check if the program output contains the flag
#     if 'flag' in output.lower():
#         print(f"Correct password found: {password}")
#         print("Flag:", output)
#         break
    break
    
# if __name__ == "__main__":
# #     run_bruteforce()
#     pass
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 14
#      10     passwords = [line.strip() for line in file]
#      12 for password in passwords:
#      13     # Execute the bruteforcer program with the current password as input
# ---> 14     process = subprocess.Popen([bruteforcer_path], stdin=subprocess.PIPE, stdout=subprocess.PIPE, text=True)
#      15     output, _ = process.communicate(input=password)
#      16 #     print('\r',password, end='')
#      17 #     # Check if the program output contains the flag
#      18 #     if 'flag' in output.lower():
#      19 #         print(f"Correct password found: {password}")
#      20 #         print("Flag:", output)
#      21 #         break
#
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\raush\\Desktop\\temp\\Cyber Security\\Cyber_security\\LS-Tools-for-Cyber-Security\\Section-2\\Challenges\\bruteforcer'

# %%
def sort_file_lexicographically(file_path):
    # Read the content of the file
    with open(file_path, 'r') as file:
        lines = file.readlines()

    # Sort the lines lexicographically
    sorted_lines = sorted(lines)

    # Write the sorted lines back to the file
    with open(file_path, 'w') as file:
        file.writelines(sorted_lines)

# Example usage:
file_path = 'wordlist.txt'
sort_file_lexicographically(file_path)

# %%
# Path to the bruteforcer program and the wordlist file
bruteforcer_path = './bruteforcer'
wordlist_path = 'wordlist.txt'
with open(wordlist_path, 'r') as file:
        passwords = [line.strip() for line in file]
import subprocess

def bst(i,f, passwords, command):
    mid = (i+f)//2
    return_value = execute_binary_with_password(passwords[mid], command)
    if "high" in return_value:
        return bst(i, mid-1, passwords, command)
    elif 'low' in return_value:
        return bst(mid+1,f, passwords, command)
    else:
        return return_value
        


def execute_binary_with_password(password, command):
    result = subprocess.run(
            [command],
            input=password.encode(),
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            check=True,
    )
    return result.stdout.decode()
    

    
res= bst(0, len(passwords)-1, passwords, bruteforcer_path)
print(res)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14816/3700106755.py in <module>
#      30
#      31
# ---> 32 res= bst(0, len(passwords)-1, passwords, bruteforcer_path)
#      33 print(res)
#
# ~\AppData\Local\Temp/ipykernel_14816/3700106755.py in bst(i, f, passwords, command)
#       8 def bst(i,f, passwords, command):
#       9     mid = (i+f)//2
# ---> 10     return_value = execute_binary_with_password(passwords[mid], command)
#      11     if "high" in return_value:
#      12         return bst(i, mid-1, passwords, command)
#
# ~\AppData\Local\Temp/ipykernel_14816/3700106755.py in execute_binary_with_password(password, command)
#      19
#      20 def execute_binary_with_password(password, command):
# ---> 21     result = subprocess.run(
#      22             [command],
#      23             input=password.encode(),
#
# ...

# %%
with open(wordlist_path, 'r') as file:
        passwords = [line.strip() for line in file]

# %%
help(subprocess)
# Out:
# Help on module subprocess:
#
# NAME
#     subprocess - Subprocesses with accessible I/O streams
#
# MODULE REFERENCE
#     https://docs.python.org/3.9/library/subprocess
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This module allows you to spawn processes, connect to their
#     input/output/error pipes, and obtain their return codes.
#
#     For a complete description of this module see the Python documentation.
#
#     Main API
# ...
#     run(...): Runs a command, waits for it to complete, then returns a
#               CompletedProcess instance.
#     Popen(...): A class for flexibly executing a command in a new process
#
#     Constants
#     ---------
# ...

# %%
import subprocess

def bst(i,f, passwords, command):
    mid = (i+f)//2
    return_value = execute_binary_with_password(passwords[mid], command)
    if "high" in return_value:
        return bst(i, mid-1, passwords, command)
    elif 'low' in return_value:
        return bst(mid+1,f, passwords, command)
    else:
        return return_value
        


def execute_binary_with_password(password, command):
    result = subprocess.run(
            [command],
            input=password.encode(),
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            check=True,
    )
    return result.stdout.decode()
    

    
res= bst(0, len(passwords)-1, passwords, bruteforcer_path)
print(res)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14816/2426842297.py in <module>
#      25
#      26
# ---> 27 res= bst(0, len(passwords)-1, passwords, bruteforcer_path)
#      28 print(res)
#
# ~\AppData\Local\Temp/ipykernel_14816/2426842297.py in bst(i, f, passwords, command)
#       3 def bst(i,f, passwords, command):
#       4     mid = (i+f)//2
# ----> 5     return_value = execute_binary_with_password(passwords[mid], command)
#       6     if "high" in return_value:
#       7         return bst(i, mid-1, passwords, command)
#
# ~\AppData\Local\Temp/ipykernel_14816/2426842297.py in execute_binary_with_password(password, command)
#      14
#      15 def execute_binary_with_password(password, command):
# ---> 16     result = subprocess.run(
#      17             [command],
#      18             input=password.encode(),
#
# ...

# %%
result = subprocess.run(
            command,
            input=password_bytes,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            check=True,
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14816/3451607228.py in <module>
#       1 result = subprocess.run(
# ----> 2             command,
#       3             input=password_bytes,
#       4             stdout=subprocess.PIPE,
#       5             stderr=subprocess.PIPE,
#
# NameError: name 'command' is not defined

# %%
import random
import string

def generate_random_string(length):
    characters = string.ascii_letters + string.digits + '_'
    return ''.join(random.choice(characters) for _ in range(length))

random_string = generate_random_string(30)
print(random_string)
# Out:
# mg2ZUmz72mB7uONT8ZpgKLF5rcP3pW
